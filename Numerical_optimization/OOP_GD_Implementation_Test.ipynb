# %%
from Model_test import model_test
import matplotlib.pyplot as plt
import numpy as np

# %%
model_test().BGD_test()
# Out:
# ====================BGD====================
# cost[-1] = 0.0009695501848239796 And cost[-2] = 0.0009745365576414929
# Iterations Number = 1007
# Epochs Number = 1007
# R2 Score = 0.9999860985656018
# ...

# %%
model_test().MBGD_test()
# Out:
# ====================MBGD====================
# cost[-1] = 2.4591875140486844e-06 And cost[-2] = 2.630169178873388e-06
# Iterations Number = 1851
# Epochs Number = 186
# R2 Score = 0.9999980702049537
# ...

# %%
model_test().SGD_test()
# Out:
# ====================SGD====================
# cost[-1] = [9.80166051e-08] And cost[-2] = [1.52451701e-07]
# Iterations Number = 2601
# Epochs Number = 53
# R2 Score = 0.9999995557889396
# ...

# %%
model_test().MomentumGD_test()
# Out:
# ====================MomentumGD====================
# cost[-1] = [1.67325722e-05] And cost[-2] = [2.03050982e-05]
# Iterations Number = 51
# Epochs Number = 2
# R2 Score = 0.9939845051828805
# ...

# %%
model_test().NAG_test()
# Out:
# ====================NAG====================
# cost[-1] = 0.0005332354021289629 And cost[-2] = 0.0005381986428565212
# Iterations Number = 624
# Epochs Number = 624
# R2 Score = 0.9999923860062718
# ...

# %%
model_test().Adagrad_test()
# Out:
# ====================Adagrad====================
# cost[-1] = 0.00029846047066119064 And cost[-2] = 0.00030343255035960513
# Iterations Number = 495
# Epochs Number = 495
# R2 Score = 0.9999957691401871
# ...

# %%
model_test().RMSProb_test()
# Out:
# ====================RMSProb====================
# cost[-1] = 3.016618100197736e-05 And cost[-2] = 3.509481310828946e-05
# Iterations Number = 122
# Epochs Number = 122
# R2 Score = 0.9999996268909064
# ...

# %%
model_test().Adam_test()
# Out:
# ====================Adam====================
# cost[-1] = 0.00010159084879244668 And cost[-2] = 0.00010296597151253572
# Iterations Number = 499
# Epochs Number = 499
# R2 Score = 0.9999954001175212
# ...
